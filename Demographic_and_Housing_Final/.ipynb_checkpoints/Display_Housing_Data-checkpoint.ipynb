# %%
import pandas as pd

# %% [markdown]
# # Read metadata
#
# ### Gives IDs for the names of the columns. Necessary because this data uses layered indexes
#
# I.E. DP05_0001E maps to Estimate!!SEX AND AGE!!Total population, which is the Estimate of the total population given in the Sex and Age section

# %%
metadata = pd.read_csv("./Demographic_And_Housing-Column-Metadata.csv")
metadata
# Out:
#      Column Name                                              Label
# 0         GEO_ID                                          Geography
# 1           NAME                               Geographic Area Name
# 2     DP05_0001E            Estimate!!SEX AND AGE!!Total population
# 3     DP05_0001M     Margin of Error!!SEX AND AGE!!Total population
# 4     DP05_0002E      Estimate!!SEX AND AGE!!Total population!!Male
# ..           ...                                                ...
# 361  DP05_0089PM  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 362  DP05_0090PE  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 363  DP05_0090PM  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 364  DP05_0091PE  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 365  DP05_0091PM  Percent Margin of Error!!CITIZEN, VOTING AGE P...
#
# [366 rows x 2 columns]

# %% [markdown]
# # Read base data from the CSV

# %%
data = pd.read_csv("./Demographic_And_Housing-Data.csv")
data
# Out:
#              GEO_ID                                  NAME  \
# 0         Geography                  Geographic Area Name
# 1    0500000US01003               Baldwin County, Alabama
# 2    0500000US01015               Calhoun County, Alabama
# 3    0500000US01043               Cullman County, Alabama
# 4    0500000US01049                DeKalb County, Alabama
# ..              ...                                   ...
# 844  0500000US72113          Ponce Municipio, Puerto Rico
# 845  0500000US72127       San Juan Municipio, Puerto Rico
# 846  0500000US72135       Toa Alta Municipio, Puerto Rico
# 847  0500000US72137       Toa Baja Municipio, Puerto Rico
# 848  0500000US72139  Trujillo Alto Municipio, Puerto Rico
#
#                                   DP05_0001E  \
# 0    Estimate!!SEX AND AGE!!Total population
# 1                                     246435
# 2                                     115788
# 3                                      90665
# ...
